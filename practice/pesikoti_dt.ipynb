# %%
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/User/Desktop/dtml/dogs_n_cats.csv')

# %%
df
# Out:
#      Длина  Высота  Шерстист  Гавкает  Лазает по деревьям      Вид
# 0       15    18.0         1        1                   0  собачка
# 1       20    24.0         1        0                   0  собачка
# 2       34    40.8         1        1                   0  собачка
# 3       26    31.2         1        1                   0  собачка
# 4       16    19.2         1        1                   0  собачка
# ..     ...     ...       ...      ...                 ...      ...
# 995      8     3.2         1        0                   1    котик
# 996      7     2.8         1        0                   1    котик
# 997      6     2.4         1        0                   1    котик
# 998      7     2.8         1        0                   1    котик
# 999     11     4.4         1        0                   1    котик
#
# [1000 rows x 6 columns]

# %%
X = df.drop(['Вид'], axis=1)
y = df.Вид

# %%
X.head()
# Out:
#    Длина  Высота  Шерстист  Гавкает  Лазает по деревьям
# 0     15    18.0         1        1                   0
# 1     20    24.0         1        0                   0
# 2     34    40.8         1        1                   0
# 3     26    31.2         1        1                   0
# 4     16    19.2         1        1                   0

# %%
clf = tree.DecisionTreeClassifier(criterion='entropy')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
plt.figure(figsize=(100, 25))
tree.plot_tree(clf, fontsize=10, feature_names=list(X), filled=True)
# Out:
# [Text(2790.0, 1019.25, 'Длина <= 14.5\nentropy = 1.0\nsamples = 670\nvalue = [335, 335]'),
#  Text(1395.0, 339.75, 'entropy = 0.0\nsamples = 335\nvalue = [335, 0]'),
#  Text(4185.0, 339.75, 'entropy = 0.0\nsamples = 335\nvalue = [0, 335]')]

# %%
clf.score(X_train, y_train)
# Out:
# 1.0

# %%
clf.fit(X_test, y_test)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
clf.score(X_test, y_test)
# Out:
# 1.0

# %%
df_test = pd.read_json('C:/Users/User/Desktop/dtml/dataset_209691_15.txt')

# %%
df_test
# Out:
#     Длина  Высота  Шерстист  Гавкает  Лазает по деревьям
# 0      18    21.6         1        1                   0
# 1      28    33.6         1        1                   0
# 2      18    21.6         1        1                   0
# 3      15    18.0         1        1                   0
# 4      15    18.0         0        1                   0
# ..    ...     ...       ...      ...                 ...
# 95     10     4.0         1        0                   1
# 96     10     4.0         1        0                   1
# 97     14     5.6         1        0                   1
# 98      8     3.2         1        0                   1
# 99     10     4.0         1        0                   1
#
# [100 rows x 5 columns]

# %%
df[:2]
# Out:
#    Длина  Высота  Шерстист  Гавкает  Лазает по деревьям      Вид
# 0     15    18.0         1        1                   0  собачка
# 1     20    24.0         1        0                   0  собачка

# %%
df_test[:2]
# Out:
#    Длина  Высота  Шерстист  Гавкает  Лазает по деревьям
# 0     18    21.6         1        1                   0
# 1     28    33.6         1        1                   0

# %%
result = clf.predict(df_test)

# %%
res_list = list(result)

# %%
res_list.count('собачка')
# Out:
# 40
