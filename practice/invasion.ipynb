# %%
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
train_data = pd.read_csv('C:/Users/User/Desktop/dtml/invasion.csv')

# %%
train_data
# Out:
#          class  g_reflection  i_reflection       speed  brightness  \
# 0    transport      2.190672      6.716633   62.168208    0.347465
# 1    transport      3.453276      8.995909   62.994707    0.590094
# 2    transport      2.432994      6.938691   62.245807    0.329288
# 3      fighter      6.083763      3.019459   18.474555    0.174738
# 4      fighter     12.876769      2.452950  195.805771    0.150446
# ..         ...           ...           ...         ...         ...
# 495    fighter      9.901731      7.162124   58.095069    0.145065
# 496  transport      3.574132      7.118835   62.928159    0.469670
# 497    fighter      9.186049      4.580781  412.102112    0.108195
# 498    fighter      8.278256      8.353756  268.121561    0.132661
# 499  transport      0.860820      8.014988   62.292486    0.304896
#
#      time_of_observance     volume
# 0                158221  44.932446
# 1                385972  41.568300
# 2                446482  40.123467
# ...

# %%
train_data = train_data.rename(columns={'class':'target'})

# %%
X = train_data.drop(['target'], axis=1)
y = train_data.target

# %%
rf = RandomForestClassifier()

# %%
parameters = {'n_estimators':range(1,10,5), 'max_depth':range(1,12,2), 
              'min_samples_leaf':range(1,7), 'min_samples_split':range(2,9,2)}

# %%
grid_search_cv_rf = GridSearchCV(rf, parameters, cv=3)

# %%
grid_search_cv_rf.fit(X, y)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': range(1, 12, 2),
#                          'min_samples_leaf': range(1, 7),
#                          'min_samples_split': range(2, 9, 2),
#                          'n_estimators': range(1, 10, 5)})

# %%
grid_search_cv_rf.best_params_
# Out:
# {'max_depth': 3,
#  'min_samples_leaf': 1,
#  'min_samples_split': 4,
#  'n_estimators': 6}

# %%
best_rf = grid_search_cv_rf.best_estimator_

# %%
test_data = pd.read_csv('C:/Users/User/Desktop/dtml/operative_information.csv')

# %%
test_data
# Out:
#       g_reflection  i_reflection       speed  brightness  time_of_observance  \
# 0         7.516543      3.916691  513.954279    0.177247              105908
# 1         4.322988      6.967689   63.752970    0.545922              277855
# 2         4.595724      9.098297   62.233948    0.389201              160662
# 3         2.689675      7.964869   62.475495    0.541081              162092
# 4         8.075576      5.169719  336.441261    0.174757              466853
# ...            ...           ...         ...         ...                 ...
# 1495     11.755466      5.583147  325.069957    0.170644              388400
# 1496     12.220137      4.023177  439.975574    0.163958              195305
# 1497      1.611053      7.864930   65.025106    0.430021              307856
# 1498      7.114131      5.532188  391.178342    0.150117               51590
# 1499      3.804275      8.038047   62.345396    0.564630               97284
#
#          volume
# 0     13.267224
# ...

# %%
y_pred = best_rf.predict(test_data)

# %%
pd.Series(y_pred).value_counts()
# Out:
# fighter      675
# transport    595
# cruiser      230
# dtype: int64

# %%
feature_importances = best_rf.feature_importances_

# %%
feature_importances_df = pd.DataFrame({'features':list(X),
                                      'feature_importances':feature_importances})

# %%
feature_importances_df.sort_values('feature_importances', ascending=False)
# Out:
#              features  feature_importances
# 5              volume             0.468603
# 3          brightness             0.245718
# 1        i_reflection             0.131799
# 0        g_reflection             0.091298
# 2               speed             0.062581
# 4  time_of_observance             0.000000

# %%
space_data = pd.read_csv('C:/Users/User/Desktop/dtml/space_can_be_a_dangerous_place.csv')

# %%
space_data
# Out:
#            r    phi  peradventure_index  dustiness  black_hole_is_near  \
# 0      169.1  138.0             22.3212   0.706285                   0
# 1       11.1  148.0              1.4652  -0.410512                   1
# 2      274.6  201.0             36.2472   0.756457                   1
# 3      172.8  173.0             22.8096   0.035221                   1
# 4      223.3  222.0             29.4756   0.197271                   0
# ...      ...    ...                 ...        ...                 ...
# 99995  301.7  249.0             39.8244   0.397064                   0
# 99996  194.0  350.0             25.6080  -1.062202                   0
# 99997  201.4  112.0             26.5848   1.571040                   0
# 99998    7.8  115.0              1.0296  -1.206575                   0
# 99999  189.3  332.0             24.9876   0.932474                   0
#
#        buggers_were_noticed  nearby_system_has_planemo  dangerous
# ...

# %%
space_data.corr()
# Out:
#                                   r       phi  peradventure_index  dustiness  \
# r                          1.000000  0.001023            1.000000  -0.003336
# phi                        0.001023  1.000000            0.001023   0.001921
# peradventure_index         1.000000  0.001023            1.000000  -0.003336
# dustiness                 -0.003336  0.001921           -0.003336   1.000000
# black_hole_is_near         0.002337  0.002875            0.002337  -0.004691
# buggers_were_noticed       0.001797 -0.004726            0.001797  -0.001290
# nearby_system_has_planemo  0.000326 -0.000803            0.000326   0.003370
# dangerous                  0.005788  0.003035            0.005788  -0.000499
#
#                            black_hole_is_near  buggers_were_noticed  \
# r                                    0.002337              0.001797
# phi                                  0.002875             -0.004726
# peradventure_index                   0.002337              0.001797
# ...

# %%
sns.heatmap(space_data.corr(), annot=True, cmap=plt.cm.Blues)
# Out:
# <AxesSubplot:>

# %%
# опасность имеет положительную корреляцию с планемо и присутствием жукеров в системе
# но не с черными дырами
